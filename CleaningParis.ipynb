# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_pickle('df_2017-paris-marathon.pkl')
df.head()
# Out:
#                                             hashedid  \
# 0  97aa97fd6749b8932310ee51786c42de6e6620151ca99e...
# 1  9936d26e1e911e076464218f45cdea420cb3c977421a01...
# 2  9936f7647f1ccad063852c7ded56cae4b5b069dec53544...
# 3  994fffa7b23dc4a26fca8b9f257986ea1cc9b83961a2e5...
# 4  9953a5727ffaf23c8586c28677d08537e4943a672fe89f...
#
#                                      hashedathleteid           startdate  \
# 0  aa07133f2cd6814410a1d27374a4b366d71dff54680250... 2017-04-09 06:35:03
# 1  9dbc447cc0a5838c17c6266795e0cfce1e6243310a6e09... 2017-04-09 06:44:16
# 2  1168e64b94165fb65f159e92e1e34df193858ec64cc5e6... 2017-04-09 07:42:37
# 3  18f3e243d30c836b38e7590b3b38174097fc9fff338ce4... 2017-04-09 07:03:53
# 4  8bff3b4e95a53b325ddc72bc1889f5750578a1275a5fc0... 2017-04-09 07:01:33
#
#        startdatelocal  totaldistance  elevgain  startlatapprox  \
# 0 2017-04-09 08:35:03        42450.6   225.437           48.87
# 1 2017-04-09 08:44:16        42864.3   274.574           48.87
# 2 2017-04-09 09:42:37        43060.5   137.000           48.87
# 3 2017-04-09 09:03:53        42824.4   267.574           48.87
# 4 2017-04-09 09:01:33        42590.9   209.000           48.87
#
#    startlngapprox  cumulative_elevation_gain  cumulative_elevation_loss  ...  \
# 0             2.3                      221.0                      203.0  ...
# 1             2.3                      213.0                      215.0  ...
# 2             2.3                      207.0                      220.0  ...
# 3             2.3                      221.0                      206.0  ...
# 4             2.3                      208.0                      218.0  ...
#
#                                                 geom  \
# 0  0101000020E61000000000006066660240000000205C6F...
# 1  0101000020E61000000000006066660240000000205C6F...
# 2  0101000020E61000000000006066660240000000205C6F...
# 3  0101000020E61000000000006066660240000000205C6F...
# 4  0101000020E61000000000006066660240000000205C6F...
#
#                                                 geog  \
# 0  0101000020E61000000000006066660240000000205C6F...
# 1  0101000020E61000000000006066660240000000205C6F...
# 2  0101000020E61000000000006066660240000000205C6F...
# 3  0101000020E61000000000006066660240000000205C6F...
# 4  0101000020E61000000000006066660240000000205C6F...
#
#                                         distance_100  \
# 0  [0.0, 100.0, 200.0, 300.0, 400.0, 500.0, 600.0...
# 1  [0.0, 100.0, 200.0, 300.0, 400.0, 500.0, 600.0...
# 2  [0.0, 100.0, 200.0, 300.0, 400.0, 500.0, 600.0...
# 3  [0.0, 100.0, 200.0, 300.0, 400.0, 500.0, 600.0...
# 4  [0.0, 100.0, 200.0, 300.0, 400.0, 500.0, 600.0...
#
#                                             time_100  \
# 0  [0.0, 32.922432, 61.723476, 92.33606, 122.5068...
# 1  [0.0, 34.39003, 68.705574, 103.31513, 138.5642...
# 2  [0.0, 29.957859, 60.528225, 92.12708, 124.1119...
# 3  [0.0, 37.98504, 72.503525, 103.4805, 136.91084...
# 4  [0.0, 32.32493, 62.78289, 92.868645, 125.19175...
#
#                                        elevation_100  \
# 0  [55.1, 53.68234, 47.011955, 48.144936, 43.9243...
# 1  [54.0, 51.000015, 47.0002, 47.32576, 43.0, 38....
# 2  [43.6, 42.002167, 40.35692, 38.96868, 38.0321,...
# 3  [53.0, 51.0, 48.28381, 44.201622, 43.0, 38.000...
# 4  [53.9, 51.624416, 47.001614, 47.284546, 42.983...
#
#                                          cadence_100  \
# 0  [1e-05, 89.68642, 90.84969, 91.01052, 90.1181,...
# 1  [1e-05, 85.10208, 84.27093, 84.44783, 84.5549,...
# 2  [85.0, 84.993484, 84.997955, 84.31958, 83.2182...
# 3  [49.0, 82.92801, 82.44078, 84.12084, 81.16607,...
# 4  [1e-05, 87.30105, 88.99528, 86.57415, 88.12192...
#
#                                        heartrate_100  \
# 0  [135.0, 134.52583, 136.93936, 141.9918, 143.97...
# 1  [118.0, 132.70236, 148.04068, 152.86617, 150.0...
# 2  [101.0, 142.00319, 142.81856, 142.03119, 143.9...
# 3  [174.0, 177.01416, 168.62338, 163.70502, 167.7...
# 4  [100.0, 121.691795, 147.4059, 144.64667, 149.5...
#
#                                        pace_diff_100  \
# 0  [1e-05, 5.372819, 4.652887, 4.825815, 4.440847...
# 1  [1e-05, 5.397174, 5.618849, 5.892455, 6.584964...
# 2  [1e-05, 4.985467, 4.695851, 5.461714, 5.437776...
# 3  [1e-05, 6.378087, 5.624665, 5.641487, 5.921052...
# 4  [1e-05, 5.627953, 5.634879, 5.40219, 4.81436, ...
#
#                                       pace_cumul_100  \
# 0  [25.0, 5.48865, 5.143669, 5.129778, 5.104453, ...
# 1  [25.0, 5.731657, 5.725456, 5.739734, 5.773501,...
# 2  [25.0, 4.993, 5.043544, 5.117977, 5.171403, 5....
# 3  [25.0, 6.330827, 6.041971, 5.748911, 5.704619,...
# 4  [25.0, 5.387364, 5.231911, 5.158942, 5.216258,...
#
#                                              gap_100
# 0  [0.0, 5.803254, 6.65404, 4.539793, 5.584803, 6...
# 1  [0.0, 6.354158, 6.982862, 5.789571, 8.328108, ...
# 2  [0.0, 5.438002, 5.135352, 5.889819, 5.721527, ...
# 3  [0.0, 7.111211, 6.520615, 7.042145, 6.320577, ...
# 4  [0.0, 6.36979, 7.240698, 5.32011, 6.080662, 6....
#
# [5 rows x 24 columns]

# %%
len(df)
# Out:
# 7502

# %%
# checking the percentage of missing values
100 * (df.isnull().sum()/df.shape[0])
# Out:
# hashedid                       0.0
# hashedathleteid                0.0
# startdate                      0.0
# startdatelocal                 0.0
# totaldistance                  0.0
# elevgain                       0.0
# startlatapprox                 0.0
# startlngapprox                 0.0
# cumulative_elevation_gain      0.0
# cumulative_elevation_loss      0.0
# activity_id                  100.0
# city_name                      0.0
# country_code                   0.0
# row_number                     0.0
# geom                           0.0
# geog                           0.0
# distance_100                   0.0
# time_100                       0.0
# elevation_100                  0.0
# cadence_100                    0.0
# heartrate_100                  0.0
# pace_diff_100                  0.0
# pace_cumul_100                 0.0
# gap_100                        0.0
# dtype: float64

# %%
# removing activity_id since it is empty
df.drop('activity_id', axis=1, inplace=True)
df.columns
# Out:
# Index(['hashedid', 'hashedathleteid', 'startdate', 'startdatelocal',
#        'totaldistance', 'elevgain', 'startlatapprox', 'startlngapprox',
#        'cumulative_elevation_gain', 'cumulative_elevation_loss', 'city_name',
#        'country_code', 'row_number', 'geom', 'geog', 'distance_100',
#        'time_100', 'elevation_100', 'cadence_100', 'heartrate_100',
#        'pace_diff_100', 'pace_cumul_100', 'gap_100'],
#       dtype='object')

# %%
# dropping all the irrelevant columns
df.drop(['startdate', 'elevgain', 'startlatapprox', 'startlngapprox', 'cumulative_elevation_gain', 'cumulative_elevation_loss', 'row_number', 'geom', 'geog'], axis=1, inplace=True)
df.head()
# Out:
#                                             hashedid  \
# 0  97aa97fd6749b8932310ee51786c42de6e6620151ca99e...
# 1  9936d26e1e911e076464218f45cdea420cb3c977421a01...
# 2  9936f7647f1ccad063852c7ded56cae4b5b069dec53544...
# 3  994fffa7b23dc4a26fca8b9f257986ea1cc9b83961a2e5...
# 4  9953a5727ffaf23c8586c28677d08537e4943a672fe89f...
#
#                                      hashedathleteid      startdatelocal  \
# 0  aa07133f2cd6814410a1d27374a4b366d71dff54680250... 2017-04-09 08:35:03
# 1  9dbc447cc0a5838c17c6266795e0cfce1e6243310a6e09... 2017-04-09 08:44:16
# 2  1168e64b94165fb65f159e92e1e34df193858ec64cc5e6... 2017-04-09 09:42:37
# 3  18f3e243d30c836b38e7590b3b38174097fc9fff338ce4... 2017-04-09 09:03:53
# 4  8bff3b4e95a53b325ddc72bc1889f5750578a1275a5fc0... 2017-04-09 09:01:33
#
#    totaldistance         city_name country_code  \
# 0        42450.6  levallois-perret           fr
# 1        42864.3  levallois-perret           fr
# 2        43060.5  levallois-perret           fr
# 3        42824.4  levallois-perret           fr
# 4        42590.9  levallois-perret           fr
#
#                                         distance_100  \
# 0  [0.0, 100.0, 200.0, 300.0, 400.0, 500.0, 600.0...
# 1  [0.0, 100.0, 200.0, 300.0, 400.0, 500.0, 600.0...
# 2  [0.0, 100.0, 200.0, 300.0, 400.0, 500.0, 600.0...
# 3  [0.0, 100.0, 200.0, 300.0, 400.0, 500.0, 600.0...
# 4  [0.0, 100.0, 200.0, 300.0, 400.0, 500.0, 600.0...
#
#                                             time_100  \
# 0  [0.0, 32.922432, 61.723476, 92.33606, 122.5068...
# 1  [0.0, 34.39003, 68.705574, 103.31513, 138.5642...
# 2  [0.0, 29.957859, 60.528225, 92.12708, 124.1119...
# 3  [0.0, 37.98504, 72.503525, 103.4805, 136.91084...
# 4  [0.0, 32.32493, 62.78289, 92.868645, 125.19175...
#
#                                        elevation_100  \
# 0  [55.1, 53.68234, 47.011955, 48.144936, 43.9243...
# 1  [54.0, 51.000015, 47.0002, 47.32576, 43.0, 38....
# 2  [43.6, 42.002167, 40.35692, 38.96868, 38.0321,...
# 3  [53.0, 51.0, 48.28381, 44.201622, 43.0, 38.000...
# 4  [53.9, 51.624416, 47.001614, 47.284546, 42.983...
#
#                                          cadence_100  \
# 0  [1e-05, 89.68642, 90.84969, 91.01052, 90.1181,...
# 1  [1e-05, 85.10208, 84.27093, 84.44783, 84.5549,...
# 2  [85.0, 84.993484, 84.997955, 84.31958, 83.2182...
# 3  [49.0, 82.92801, 82.44078, 84.12084, 81.16607,...
# 4  [1e-05, 87.30105, 88.99528, 86.57415, 88.12192...
#
#                                        heartrate_100  \
# 0  [135.0, 134.52583, 136.93936, 141.9918, 143.97...
# 1  [118.0, 132.70236, 148.04068, 152.86617, 150.0...
# 2  [101.0, 142.00319, 142.81856, 142.03119, 143.9...
# 3  [174.0, 177.01416, 168.62338, 163.70502, 167.7...
# 4  [100.0, 121.691795, 147.4059, 144.64667, 149.5...
#
#                                        pace_diff_100  \
# 0  [1e-05, 5.372819, 4.652887, 4.825815, 4.440847...
# 1  [1e-05, 5.397174, 5.618849, 5.892455, 6.584964...
# 2  [1e-05, 4.985467, 4.695851, 5.461714, 5.437776...
# 3  [1e-05, 6.378087, 5.624665, 5.641487, 5.921052...
# 4  [1e-05, 5.627953, 5.634879, 5.40219, 4.81436, ...
#
#                                       pace_cumul_100  \
# 0  [25.0, 5.48865, 5.143669, 5.129778, 5.104453, ...
# 1  [25.0, 5.731657, 5.725456, 5.739734, 5.773501,...
# 2  [25.0, 4.993, 5.043544, 5.117977, 5.171403, 5....
# 3  [25.0, 6.330827, 6.041971, 5.748911, 5.704619,...
# 4  [25.0, 5.387364, 5.231911, 5.158942, 5.216258,...
#
#                                              gap_100
# 0  [0.0, 5.803254, 6.65404, 4.539793, 5.584803, 6...
# 1  [0.0, 6.354158, 6.982862, 5.789571, 8.328108, ...
# 2  [0.0, 5.438002, 5.135352, 5.889819, 5.721527, ...
# 3  [0.0, 7.111211, 6.520615, 7.042145, 6.320577, ...
# 4  [0.0, 6.36979, 7.240698, 5.32011, 6.080662, 6....

# %%
# checking for duplicate rows and keeping the first instance 
df.drop_duplicates(subset=['hashedid'], keep='first', inplace=True)

# %%
df.to_pickle("./cleanedParis.pkl")
